# %%
import pandas as pd
df = pd.read_excel('DummyData\IncomeData\Shopee\shopee_dummy_income_released.xlsx',sheet_name='Income', header = 5)
df
# Out:
#    Sequence No.        Order ID     refund id Username (Buyer)  \
# 0             1  DUMMY_SHOPEE_1  4.561452e+12             ****
# 1             2  DUMMY_SHOPEE_2           NaN             ****
# 2             3  DUMMY_SHOPEE_3           NaN             ****
# 3             4  DUMMY_SHOPEE_4           NaN             ****
# 4             5  DUMMY_SHOPEE_5           NaN             ****
#
#   Order Creation Date Buyer Payment Method  \
# 0          2024-08-06            SPayLater
# 1          2024-08-08       Online Banking
# 2          2024-08-07       Online Banking
# 3          2024-08-03            ShopeePay
# 4          2024-08-09       Online Banking
#
#    Buyer Payment Method Details_1(if applicable)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# ...

# %%
df.drop(columns = 'Sequence No.',inplace=True)
df
# Out:
#          Order ID     refund id Username (Buyer) Order Creation Date  \
# 0  DUMMY_SHOPEE_1  4.561452e+12             ****          2024-08-06
# 1  DUMMY_SHOPEE_2           NaN             ****          2024-08-08
# 2  DUMMY_SHOPEE_3           NaN             ****          2024-08-07
# 3  DUMMY_SHOPEE_4           NaN             ****          2024-08-03
# 4  DUMMY_SHOPEE_5           NaN             ****          2024-08-09
#
#   Buyer Payment Method  Buyer Payment Method Details_1(if applicable)  \
# 0            SPayLater                                            NaN
# 1       Online Banking                                            NaN
# 2       Online Banking                                            NaN
# 3            ShopeePay                                            NaN
# 4       Online Banking                                            NaN
#
#   Payment Details / Installment Plan Transaction Fee Rate (%)  \
# 0                                 1x                    3.78%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 39 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Order ID                                                             5 non-null      object
#  1   refund id                                                            1 non-null      float64
#  2   Username (Buyer)                                                     5 non-null      object
#  3   Order Creation Date                                                  5 non-null      object
#  4   Buyer Payment Method                                                 5 non-null      object
#  5   Buyer Payment Method Details_1(if applicable)                        0 non-null      float64
#  6   Payment Details / Installment Plan                                   1 non-null      object
# ...

# %%
# Cast date time accordingly
date_columns = df.columns[df.columns.str.lower().str.contains('date')]
print(list(date_columns))
df[date_columns] = df[date_columns].apply(pd.to_datetime)
df.info()
# Out:
# ['Order Creation Date', 'Payout Completed Date']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 39 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Order ID                                                             5 non-null      object
#  1   refund id                                                            1 non-null      float64
#  2   Username (Buyer)                                                     5 non-null      object
#  3   Order Creation Date                                                  5 non-null      datetime64[ns]
#  4   Buyer Payment Method                                                 5 non-null      object
#  5   Buyer Payment Method Details_1(if applicable)                        0 non-null      float64
# ...

# %%
df
# Out:
#          Order ID     refund id Username (Buyer) Order Creation Date  \
# 0  DUMMY_SHOPEE_1  4.561452e+12             ****          2024-08-06
# 1  DUMMY_SHOPEE_2           NaN             ****          2024-08-08
# 2  DUMMY_SHOPEE_3           NaN             ****          2024-08-07
# 3  DUMMY_SHOPEE_4           NaN             ****          2024-08-03
# 4  DUMMY_SHOPEE_5           NaN             ****          2024-08-09
#
#   Buyer Payment Method  Buyer Payment Method Details_1(if applicable)  \
# 0            SPayLater                                            NaN
# 1       Online Banking                                            NaN
# 2       Online Banking                                            NaN
# 3            ShopeePay                                            NaN
# 4       Online Banking                                            NaN
#
#   Payment Details / Installment Plan Transaction Fee Rate (%)  \
# 0                                 1x                    3.78%
# ...

# %%
from sqlalchemy import create_engine
server_name = 'MSI\SQLEXPRESS'
driver = 'ODBC Driver 17 for SQL Server'
database = 'Kaizen_db'
table_name = 'Shopee_Income'
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database}?driver={driver}&trusted_connection=yes")
try:
    df.to_sql(table_name, engine, if_exists='append', index=False)
    print('Data appended to server successfully')
except Exception as e:
    print(f'Error occured {e}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sqlalchemy import create_engine
#       2 server_name = 'MSI\SQLEXPRESS'
#       3 driver = 'ODBC Driver 17 for SQL Server'
#
# ModuleNotFoundError: No module named 'sqlalchemy'
